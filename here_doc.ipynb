# %%
#start a web server using python
# %%bash
/cygdrive/c/Anaconda3/python.exe -m http.server 9001

# %%
# %%bash
# cat <<- EOF > index.html
# <html>
#     <head>
#         <title>IT3</title>
#     </head>
#     <body>
#         <pre>
# Welcome to Advanced Scripting
#         </pre>
#     </body>
# </html>
# EOF

# %%
# %%bash
# ls

# %%
print("hello")

# %%
dir({})

# %%
sentence = "this is a long sentence"

freq = {}

for char in sentence.replace(" ",""):
    freq[char] = freq.get(char, "*") * 2

freq

# %%
a =1
b =4

a if a > b else b

# %%
# !ipconfig > test.txt

# %%
# %%bash
# ls
# Out:
# apache.log
# classes.ipynb
# file.dat
# file_io.ipynb
# helloworld.py
# here_doc.ipynb
# index.html
# jupyter intro.ipynb
# lab_06_data_structures.ipynb
# lab_07_apache_log_files.ipynb
# Lab10_exercises.ipynb
# lab10solutions.ipynb
# lab11.ipynb
# lab2.ipynb
# lab3.ipynb
# lab4.ipynb
# lab5.ipynb
# lab6.ipynb
# lab9.ipynb
# numbers.dat
# test.txt

# %%
with open("test.txt") as f:
    test = f.read()
print(test)
print(type(test))
for i in test:
    print(i)
# Out:
# Windows IP Configuration
#
#
# Ethernet adapter Local Area Connection:
#
#    Connection-specific DNS Suffix  . : students.ittralee.local
#    IPv4 Address. . . . . . . . . . . : 10.5.32.186
#    Subnet Mask . . . . . . . . . . . : 255.255.255.0
#    Default Gateway . . . . . . . . . : 10.5.32.1
#
# Ethernet adapter Local Area Connection 2:
#
#    Connection-specific DNS Suffix  . :
#    IPv4 Address. . . . . . . . . . . : 192.168.56.1
#    Subnet Mask . . . . . . . . . . . : 255.255.255.0
#    Default Gateway . . . . . . . . . :
#
# <class 'str'>
#
#
# W
# i
# n
# d
# o
# w
# s
#
# I
# P
#
# C
# o
# n
# f
# i
# g
# u
# r
# a
# t
# i
# o
# n
#
#
#
#
#
#
# E
# t
# h
# e
# r
# n
# e
# t
#
# a
# d
# a
# p
# t
# e
# r
#
# L
# o
# c
# a
# l
#
# A
# r
# e
# a
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
# :
#
#
#
#
#
#
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
# -
# s
# p
# e
# c
# i
# f
# i
# c
#
# D
# N
# S
#
# S
# u
# f
# f
# i
# x
#
#
# .
#
# :
#
# s
# t
# u
# d
# e
# n
# t
# s
# .
# i
# ...

# %%
type((1,2,3))
# Out:
# tuple

# %%
file = open("test.txt")

print(file.read())

print(type(file))

file.close()
# Out:
# Windows IP Configuration
#
#
# Ethernet adapter Local Area Connection:
#
#    Connection-specific DNS Suffix  . : students.ittralee.local
#    IPv4 Address. . . . . . . . . . . : 10.5.32.186
#    Subnet Mask . . . . . . . . . . . : 255.255.255.0
#    Default Gateway . . . . . . . . . : 10.5.32.1
#
# Ethernet adapter Local Area Connection 2:
#
#    Connection-specific DNS Suffix  . :
#    IPv4 Address. . . . . . . . . . . : 192.168.56.1
#    Subnet Mask . . . . . . . . . . . : 255.255.255.0
#    Default Gateway . . . . . . . . . :
#
# <class '_io.TextIOWrapper'>

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
nums =["one","two", "three"]
print(nums)
# Out:
# ['one', 'two', 'three']

# %%
print(" ".join(nums))
# Out:
# one two three
